# %%
import pandas as pd
df = pd.read_csv("../../data/raw/TSLA.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("../data/raw/TSLA.csv")
#       4 df.head()
#
# File ~\Desktop\TOP\data-analytics-projects\1.exploring-stock-prices\env\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\Desktop\TOP\data-analytics-projects\1.exploring-stock-prices\env\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\Desktop\TOP\data-analytics-projects\1.exploring-stock-prices\env\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\Desktop\TOP\data-analytics-projects\1.exploring-stock-prices\env\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\Desktop\TOP\data-analytics-projects\1.exploring-stock-prices\env\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/TSLA.csv'

# %%
import pandas as pd
df = pd.read_csv("../../data/raw/TSLA.csv")

df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  73401000
# 1  2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333  85279500
# 2  2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667  60204000
# 3  2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000  65340000
# 4  2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333  65469000

# %%
df.shape
# Out:
# (1258, 7)

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000  \
# mean    141.183041   144.468851   137.572984   141.093711   141.093711
# std     115.246910   117.845138   112.282411   115.068959   115.068959
# min      12.073333    12.445333    11.799333    11.931333    11.931333
# 25%      21.644667    22.190000    21.240500    21.854334    21.854334
# 50%     138.441673   141.926666   135.418335   138.178330   138.178330
# 75%     235.611672   239.940838   231.327495   236.144165   236.144165
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  1.258000e+03
# mean   1.359143e+08
# std    8.971719e+07
# min    2.940180e+07
# 25%    7.747990e+07
# 50%    1.065255e+08
# 75%    1.658194e+08
# max    9.140820e+08

# %%
df['Open'].min()
# Out:
# 12.073333

# %%
df['daily_returns'] = df['Close'].pct_change()
print(df.head())
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  \
# 1  2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333
# 2  2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667
# 3  2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000
# 4  2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333
#
#      Volume  daily_returns
# 0  73401000            NaN
# 1  85279500       0.000318
# 2  60204000      -0.009772
# 3  65340000       0.017065
# 4  65469000       0.030125

# %%
print(df.head())
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  \
# 1  2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333
# 2  2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667
# 3  2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000
# 4  2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333
#
#      Volume  daily_returns
# 0  73401000            NaN
# 1  85279500       0.000318
# 2  60204000      -0.009772
# 3  65340000       0.017065
# 4  65469000       0.030125

# %%
df['MA30'] = df['Close'].rolling(window=30).mean()
print(df.head())
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  \
# 1  2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333
# 2  2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667
# 3  2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000
# 4  2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333
#
#      Volume  daily_returns  MA30
# 0  73401000            NaN   NaN
# 1  85279500       0.000318   NaN
# 2  60204000      -0.009772   NaN
# 3  65340000       0.017065   NaN
# 4  65469000       0.030125   NaN

# %%
print(df.head(45))
# Out:
#           Date       Open       High        Low      Close  Adj Close
# 0   2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  \
# 1   2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333
# 2   2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667
# 3   2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000
# 4   2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333
# 5   2018-04-30  19.573999  19.915333  19.500000  19.593332  19.593332
# 6   2018-05-01  19.567333  20.054667  19.548000  19.994667  19.994667
# 7   2018-05-02  19.904667  20.456667  19.851999  20.076668  20.076668
# 8   2018-05-03  18.586000  19.202667  18.348667  18.963333  18.963333
# 9   2018-05-04  18.866667  19.790667  18.634666  19.606001  19.606001
# 10  2018-05-07  19.833332  20.397333  19.677999  20.184668  20.184668
# 12   85911000       0.016161        NaN
# 13   84774000      -0.005964        NaN
# 14   70194000      -0.012983        NaN
# 15  109302000      -0.030193        NaN
# 16  142788000      -0.026681        NaN
# 17   85110000       0.008093        NaN
# 18   66309000      -0.006772        NaN
# 19  108778500      -0.027132        NaN
# 20  137739000       0.027708        NaN
# 21  134187000      -0.033323        NaN
# 22   89776500       0.014763        NaN
# 23   62650500      -0.004372        NaN
# 24   58126500       0.003599        NaN
# 25   84999000       0.017608        NaN
# 26  112345500       0.028052        NaN
# 27   88795500      -0.023961        NaN
# 28   81366000       0.024901        NaN
# 29   71967000       0.016860  19.302867
# 30   89928000      -0.018905  19.320111
# 31  281509500       0.097448  19.400200
# 32  215179500      -0.010673  19.478867
# 33  123078000       0.004967  19.550378
# 34  197752500       0.045457  19.634867
# 35  335211000       0.032129  19.743467
# 36  142047000       0.005864  19.843156
# 37  164715000       0.037531  19.968867
# 38  162724500       0.001258  20.132689
# 39  181098000       0.035346  20.303222
# 40  191428500      -0.049295  20.413844
# 41  125755500       0.027429  20.547733
# 42  119506500      -0.040611  20.638089
# 43  153991500      -0.039941  20.701667
# 44  103969500      -0.001858  20.772667

# %%
df['MA50'] = df['Close'].rolling(window=50).mean()
print(df.head(100))
# Out:
#           Date       Open       High        Low      Close  Adj Close
# 0   2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  \
# 1   2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333
# 2   2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667
# 3   2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000
# 4   2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333
# ..         ...        ...        ...        ...        ...        ...
# 95  2018-09-06  18.986668  19.411333  18.591999  18.730000  18.730000
# 96  2018-09-07  17.340000  17.889999  16.816668  17.549334  17.549334
# 97  2018-09-10  18.217333  19.068666  18.066668  19.033333  19.033333
# 98  2018-09-11  18.631332  18.799999  18.236668  18.629333  18.629333
# 99  2018-09-12  18.762667  19.500000  18.576668  19.369333  19.369333
#
#        Volume  daily_returns       MA30       MA50
# 0    73401000            NaN        NaN        NaN
# 1    85279500       0.000318        NaN        NaN
# 2    60204000      -0.009772        NaN        NaN
# 3    65340000       0.017065        NaN        NaN
# 4    65469000       0.030125        NaN        NaN
# ..        ...            ...        ...        ...
# 95  112212000       0.000748  21.468244  21.409893
# 96  337378500      -0.063036  21.371778  21.301547
# 97  214252500       0.084562  21.345822  21.215640
# 98  137550000      -0.021226  21.321978  21.130960
# 99  150231000       0.039722  21.305089  21.071587
#
# [100 rows x 10 columns]

# %%
df['MA200'] = df['Close'].rolling(window=200).mean()
print(df.head(250))
# Out:
#            Date       Open       High        Low      Close  Adj Close
# 0    2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  \
# 1    2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333
# 2    2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667
# 3    2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000
# 4    2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333
# ..          ...        ...        ...        ...        ...        ...
# 245  2019-04-12  18.014668  18.129999  17.788668  17.846666  17.846666
# 246  2019-04-15  17.908667  17.925333  17.242001  17.758667  17.758667
# 247  2019-04-16  17.716667  18.333332  17.648001  18.224001  18.224001
# 248  2019-04-17  18.316668  18.319332  17.902666  18.082001  18.082001
# 249  2019-04-18  18.082001  18.322666  17.983334  18.217333  18.217333
#
#         Volume  daily_returns       MA30       MA50      MA200
# 0     73401000            NaN        NaN        NaN        NaN
# 1     85279500       0.000318        NaN        NaN        NaN
# 2     60204000      -0.009772        NaN        NaN        NaN
# 3     65340000       0.017065        NaN        NaN        NaN
# 4     65469000       0.030125        NaN        NaN        NaN
# ..         ...            ...        ...        ...        ...
# 245  101190000      -0.002682  18.456467  19.262720  20.727443
# 246  150579000      -0.004931  18.414289  19.201613  20.701403
# 247  109093500       0.026203  18.407222  19.148907  20.675880
# 248   76897500      -0.007792  18.396089  19.082080  20.651973
# 249   88144500       0.007484  18.388689  19.023467  20.631370
#
# [250 rows x 11 columns]

# %%
print(df.head())
# Out:
#          Date       Open       High        Low      Close  Adj Close
# 0  2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  \
# 1  2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333
# 2  2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667
# 3  2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000
# 4  2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333
#
#      Volume  daily_returns  MA30  MA50  MA200
# 0  73401000            NaN   NaN   NaN    NaN
# 1  85279500       0.000318   NaN   NaN    NaN
# 2  60204000      -0.009772   NaN   NaN    NaN
# 3  65340000       0.017065   NaN   NaN    NaN
# 4  65469000       0.030125   NaN   NaN    NaN

# %%
lookback_period = 14
delta = df['Close'].diff()
up = delta.where(delta > 0, 0)
down = -delta.where(delta < 0, 0)
avg_gain = up.rolling(window=lookback_period).mean()
avg_loss = down.rolling(window=lookback_period).mean()
rs = avg_gain / avg_loss
df['RSI'] = 100 - (100 / (1 + rs))
print(df.head(250))
# Out:
#            Date       Open       High        Low      Close  Adj Close
# 0    2018-04-23  19.419333  19.441334  18.822001  18.891333  18.891333  \
# 1    2018-04-24  19.000000  19.139334  18.563999  18.897333  18.897333
# 2    2018-04-25  18.900000  19.010668  18.483334  18.712667  18.712667
# 3    2018-04-26  18.583332  19.052668  18.433332  19.032000  19.032000
# 4    2018-04-27  19.024668  19.631332  18.922001  19.605333  19.605333
# ..          ...        ...        ...        ...        ...        ...
# 245  2019-04-12  18.014668  18.129999  17.788668  17.846666  17.846666
# 246  2019-04-15  17.908667  17.925333  17.242001  17.758667  17.758667
# 247  2019-04-16  17.716667  18.333332  17.648001  18.224001  18.224001
# 248  2019-04-17  18.316668  18.319332  17.902666  18.082001  18.082001
# 249  2019-04-18  18.082001  18.322666  17.983334  18.217333  18.217333
#
#         Volume  daily_returns       MA30       MA50      MA200        RSI
# 0     73401000            NaN        NaN        NaN        NaN        NaN
# 1     85279500       0.000318        NaN        NaN        NaN        NaN
# 2     60204000      -0.009772        NaN        NaN        NaN        NaN
# 3     65340000       0.017065        NaN        NaN        NaN        NaN
# 4     65469000       0.030125        NaN        NaN        NaN        NaN
# ..         ...            ...        ...        ...        ...        ...
# 245  101190000      -0.002682  18.456467  19.262720  20.727443  54.335382
# 246  150579000      -0.004931  18.414289  19.201613  20.701403  49.108171
# 247  109093500       0.026203  18.407222  19.148907  20.675880  49.055877
# 248   76897500      -0.007792  18.396089  19.082080  20.651973  45.150293
# 249   88144500       0.007484  18.388689  19.023467  20.631370  45.713176
#
# [250 rows x 12 columns]
